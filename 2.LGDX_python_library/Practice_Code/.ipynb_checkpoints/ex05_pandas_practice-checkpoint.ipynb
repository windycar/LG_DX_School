# %%
import pandas as pd
import os

# %%
t=pd.read_csv(r"C:\Users\jyc68\LG_DX_school_code\data\train.csv",encoding="euc-kr",index_col="PassengerId")
t[t['Embarked']=='S']
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 7                   0       1                       McCarthy, Mr. Timothy J
# ...               ...     ...                                           ...
# 884                 0       2                 Banfield, Mr. Frederick James
# 885                 0       3                        Sutehall, Mr. Henry Jr
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
t.shape
# Out:
# (891, 11)

# %%
t.info
# Out:
# <bound method DataFrame.info of              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...

# %%
t[t['Age'].isnull()]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 6                   0       3                          Moran, Mr. James
# 18                  1       2              Williams, Mr. Charles Eugene
# 20                  1       3                   Masselmani, Mrs. Fatima
# 27                  0       3                   Emir, Mr. Farred Chehab
# 29                  1       3             O'Dwyer, Miss. Ellen "Nellie"
# ...               ...     ...                                       ...
# 860                 0       3                          Razi, Mr. Raihed
# 864                 0       3         Sage, Miss. Dorothy Edith "Dolly"
# 869                 0       3               van Melkebeke, Mr. Philemon
# 879                 0       3                        Laleff, Mr. Kristo
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#                 Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# ...

# %%
t[t['Survived']==1]['Sex'].value_counts('M')*100
# Out:
# Sex
# female    68.128655
# male      31.871345
# Name: proportion, dtype: float64

# %% [markdown]
# ## 3.전처리 응용 실습
# 3-1 AGE 결측치를 전체의 평균 으로 채우기

# %%
a=t['Age'].notnull()
c=t['Age'].isnull()

# %%
tmp=t[a]['Age'].mean().astpye(int)
tmp
# Out:
# np.float64(30.0)

# %%
t['Age']df.fillna(특정값)

# %%
t
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
male_mean=t[t['Sex']=='male']['Age'].mean().astype(int)

# %%
male_mean
# Out:
# np.int64(30)

# %%
female_mean=t[t['Sex']=='female']['Age'].mean().astype(int)

# %%
female_mean
# Out:
# np.int64(27)

# %%
t.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
t.groupby('Sex')['Age'].transform('median')# 전부다 채워버리는 문제
# Out:
# PassengerId
# 1      29.0
# 2      27.0
# 3      27.0
# 4      27.0
# 5      29.0
#        ...
# 887    29.0
# 888    27.0
# 889    27.0
# 890    29.0
# 891    29.0
# Name: Age, Length: 891, dtype: float64

# %%
t['Age']=t['Age'].fillna(t.groupby('Sex')['Age'].transform('median'))

# %%
t['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
t['Embarked'].value_counts().index[0]
# Out:
# 'S'

# %%
a=sorted(t['Embarked'].unique())
print(a[len(a)-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 a=sorted(t['Embarked'].unique())
#       2 print(a[len(a)-1])
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
t['Embarked']=t['Embarked'].fillna(t['Embarked'].value_counts().index[0])

# %%
t[t['Embarked']== 'S']
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 7                   0       1                       McCarthy, Mr. Timothy J
# ...               ...     ...                                           ...
# 884                 0       2                 Banfield, Mr. Frederick James
# 885                 0       3                        Sutehall, Mr. Henry Jr
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
t
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
t['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
t['Embarked'].isnull().sum()
# Out:
# np.int64(0)
