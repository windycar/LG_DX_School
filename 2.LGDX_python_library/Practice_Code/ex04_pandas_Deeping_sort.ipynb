# %%
# 데이터 병합 및 정렬

# %% [markdown]
# ### 학습 목표
# - 목적의 맞게 데이터를 준비하고 다듬는 방법을 알아보자

# %%
import pandas as pd
import os

# %%
os.getcwd() # 현재 파일 절대 경로
# Out:
# 'C:\\Users\\jyc68\\LG_DX_school_code\\2.LGDX_python_library\\Practice_Materials'

# %%
#현재 파일기준 들어있는 파일 리스트 
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'ex01_numpy.ipynb',
#  'ex02_pandas.ipynb',
#  'ex03_pandas_Deepening(Exploration_of_Descriptive_Statistics).ipynb',
#  'ex03_pandas_Deeping_sort.ipynb']

# %%
#특정 위치 폴덜 들어있느 파일 리스트 
os.listdir(r"C:\Users\jyc68\LG_DX_school_code\data")
# Out:
# ['height_weight.txt',
#  'hr-info.csv',
#  'Monthly_pay',
#  'movie_review.pkl',
#  'ratings.txt',
#  '육군신체측정정보.csv']

# %%
# 파일 3개 불어오기
pd.read_csv(r"C:\Users\jyc68\LG_DX_school_code\data\Monthly_pay\hr-pay-info-4월.csv",encoding="euc-kr")
pd.read_csv(r"C:\Users\jyc68\LG_DX_school_code\data\Monthly_pay\hr-pay-info-5월.csv",encoding="euc-kr")
pd.read_csv(r"C:\Users\jyc68\LG_DX_school_code\data\Monthly_pay\hr-pay-info-6월.csv",encoding="euc-kr")
# Out:
#         EID  PAYMENT_DY PAYMENT_DVCD  PAYMENT_AMOUNT
# 0    E00206    20240601           월급             850
# 1    E00181    20240601           월급             791
# 2    E00164    20240601           월급             758
# 3    E00190    20240601           월급             708
# 4    E00209    20240601           월급             716
# ..      ...         ...          ...             ...
# 146  E00322    20240601           월급             375
# 147  E00389    20240601           월급             375
# 148  E00438    20240601           월급             375
# 149  E00304    20240601           월급             375
# 150  E00428    20240601           월급             375
#
# [151 rows x 4 columns]

# %%
os.listdir(r"C:\Users\jyc68\LG_DX_school_code\data\Monthly_pay")
# Out:
# ['hr-pay-info-4월.csv', 'hr-pay-info-5월.csv', 'hr-pay-info-6월.csv']

# %%
p=[]
for i in os.listdir(r"C:\Users\jyc68\LG_DX_school_code\data\Monthly_pay"):
    tmp=pd.read_csv(r"C:\Users\jyc68\LG_DX_school_code\data\Monthly_pay\\"+i ,encoding="euc-kr")
    p.append(tmp)

# %%
os.listdir("../../data/Monthly_pay/")
# Out:
# ['hr-pay-info-4월.csv', 'hr-pay-info-5월.csv', 'hr-pay-info-6월.csv']

# %%
pay_list=[]
for i in os.listdir("../../data/Monthly_pay/"):
    tmp=pd.read_csv("../../data/Monthly_pay/"+i ,encoding="euc-kr")
    pay_list.append(tmp)

# %% [markdown]
# ### DataFrame 병합하기(합치기)-> concat
# - pd.concat(df1,df2,.... ,axis= 0 or 1)
#     - 축설정
#     - axis = 0 : 행방향으로 병합(위에서 아래 방향으로 병합 )
#     - axis = 1 : 행방향으로 병합(위에서 아래 방향으로 병합 )
#     - default 값은 axis = 0

# %% [markdown]
# ![image.png](attachment:b84d5ebd-6312-4fda-a6e4-e745520854a2.png)

# %%
pay=pd.concat(p)

# %%
a
# Out:
#         EID  PAYMENT_DY PAYMENT_DVCD  PAYMENT_AMOUNT
# 0    E00206    20240401           월급             850
# 1    E00181    20240401           월급             791
# 2    E00164    20240401           월급             758
# 3    E00190    20240401           월급             708
# 4    E00209    20240401           월급             716
# ..      ...         ...          ...             ...
# 146  E00322    20240601           월급             375
# 147  E00389    20240601           월급             375
# 148  E00438    20240601           월급             375
# 149  E00304    20240601           월급             375
# 150  E00428    20240601           월급             375
#
# [755 rows x 4 columns]

# %%
b=pd.concat(p,axis=1)

# %%
b
# Out:
#         EID  PAYMENT_DY PAYMENT_DVCD  PAYMENT_AMOUNT     EID  PAYMENT_DY  \
# 0    E00206    20240401           월급             850  E00206  20240501.0
# 1    E00181    20240401           월급             791  E00181  20240501.0
# 2    E00164    20240401           월급             758  E00164  20240501.0
# 3    E00190    20240401           월급             708  E00190  20240501.0
# 4    E00209    20240401           월급             716  E00209  20240501.0
# ..      ...         ...          ...             ...     ...         ...
# 448  E00322    20240401          상여금             300     NaN         NaN
# 449  E00389    20240401          상여금             300     NaN         NaN
# 450  E00438    20240401          상여금             300     NaN         NaN
# 451  E00304    20240401          상여금             300     NaN         NaN
# 452  E00428    20240401          상여금             300     NaN         NaN
#
#     PAYMENT_DVCD  PAYMENT_AMOUNT     EID  PAYMENT_DY PAYMENT_DVCD  \
# ...

# %%
hr_pay=a.to_csv('../../data/total_pay.csv',index=False)

# %% [markdown]
# - org_info.csv 파일을 읽어와 org_info 변수에 저장
#      - 인코딩 :'euc-kr'
#      - 'ORG_CD'컬럼을 인덱스로 변경"

# %%
org=pd.read_csv(r"C:\Users\jyc68\LG_DX_school_code\data\org-info.csv",encoding="euc-kr",index_col='ORG_CD')

# %%
hr=pd.read_csv('../../data/hr-info.csv',encoding='euc-kr')
hr
# Out:
#         EID ENAME GENDER  ORG_CD POS_CD  AGE  SERVICE_YEAR EDU_LEVEL  \
# 0    E00206   시이오      M     NaN   P001   49            25     박사 학위
# 1    E00181   나사장      F     NaN   P002   49            24     박사 학위
# 2    E00164  난부사장      M     NaN   P003   48            22     박사 학위
# 3    E00190   판라다      F  ORG007   P004   47            18     박사 학위
# 4    E00209   누훈봉      M  ORG023   P004   47            19     박사 학위
# ..      ...   ...    ...     ...    ...  ...           ...       ...
# 195  E00322   부탐회      F  ORG014   P009   23             0     학사 학위
# 196  E00389   초두반      F  ORG012   P009   23             0     학사 학위
# 197  E00438   권개득      M  ORG024   P009   23             0     학사 학위
# 198  E00304   탐출조      M  ORG009   P009   24             0     학사 학위
# 199  E00428   을충나      F  ORG003   P009   24             0     학사 학위
#
#      PERFORMANCE_SCORE  SALARY LAST_PROMO_DT  TRAINING_HOURS  \
# 0                 4.50   10200    2024-03-01             240
# ...

# %%
org_agg=hr.groupby('ORG_CD').agg({'ORG_CD':'count',
                         'AGE':'mean',
                         'SERVICE_YEAR':'mean',
                         'SALARY':'mean'}).round(2)
#컬럼이름 수치에 맞게 변경

# %%
org_agg.columns=['HEAD_COUNT',"AGE_MEAN","SERVICE_MEAN","SALARY_MEAN"]
org_agg
# Out:
#         HEAD_COUNT  AGE_MEAN  SERVICE_MEAN  SALARY_MEAN
# ORG_CD
# ORG001           6     26.17          0.33      5033.33
# ORG002           4     34.00          7.50      6550.00
# ORG003           5     34.60          7.60      6480.00
# ORG004          11     35.18          7.00      6445.45
# ORG005           8     29.25          2.00      5525.00
# ORG006           6     30.83          4.17      5966.67
# ORG007           7     36.71          8.00      6728.57
# ORG008           5     32.40          5.20      6020.00
# ORG009           5     29.80          2.20      5520.00
# ORG010           3     33.33          5.67      6300.00
# ORG011           5     37.40          8.40      6660.00
# ORG012           5     29.60          2.60      5680.00
# ORG013           8     32.62          3.62      5950.00
# ORG014           8     32.75          5.00      6025.00
# ORG015           3     24.67          0.00      5000.00
# ORG016           8     35.00          7.25      6500.00
# ...

# %%
# org_info와 데이터와 조직원 데이터에서 추출한 결과인 org_agg 병합
# concat 인덱스 번호가 같은데이터끼리 변합 (열방형 병합)->org_info_result

# %%
org_info_result=pd.concat([org,org_agg],axis=1)

# %%
org_info_result
# Out:
#                                      ENG_DIVISION KOR_DIVISION  \
# ORG_CD
# ORG001                Home Entertainment Division       HE사업본부
# ORG002                Home Entertainment Division       HE사업본부
# ORG003                Home Entertainment Division       HE사업본부
# ORG004                Home Entertainment Division       HE사업본부
# ORG005                Home Entertainment Division       HE사업본부
# ORG006                Home Entertainment Division       HE사업본부
# ORG007                 Vehicle Solutions Division       VS사업본부
# ORG008                 Vehicle Solutions Division       VS사업본부
# ORG009                 Vehicle Solutions Division       VS사업본부
# ORG010                 Vehicle Solutions Division       VS사업본부
# ORG011                 Vehicle Solutions Division       VS사업본부
# ORG012                 Vehicle Solutions Division       VS사업본부
# ORG013   Home Appliance and Air Solution Division       HA사업본부
# ORG014   Home Appliance and Air Solution Division       HA사업본부
# ...

# %% [markdown]
# ![image.png](attachment:0722fcac-54a0-448a-81d2-151b7361ac08.png)

# %%
hr_pay=pay

# %% [markdown]
# ### DataFrame 병합 (합치기) - Merge
# - 두개의 DF에서 공통된 키값을 기준으로 병합
# - 데이터의 정보를 기준으로 병합 -> 두개의 DataFrame 에 공통으로 존재
# -  Merge 특징
#     - join 속성
#         - inner: 교집합 병합(기본 )
#         - outer : 합집합 병합
#         - left : 왼쪽 데이터 프레임 기준
#         - right : 오른쪽 데이터 프레임 기준

# %% [markdown]
# ### Concat, Merge 차이점
# - concat
#   - 병합기준: 인덱스명, 컬럼명
#   - 단순연결 (행추가, 열추가)
# - merge
#   - 병합기준: 데이터값 (공통된 키값)
#   - 데이터셋 간의 관계를 바탕으로 결합

# %% [markdown]
# - hr,hr_pay 두개의 DF를 통해 직원별 급여내역 정리

# %%
# 직원정보에서 필요 컬럼 만 추충
#EID,ENAME,GEDER
hr_df=hr[['EID','ENAME','GENDER']]

# %%
hr_df.shape
# Out:
# (200, 3)

# %%
#병합 진행
#pd.merge(df1,df2,on='병합 기준이 되는 키 컬럼명 ',how='join 방식')
pd.merge(hr_df,hr_pay,on='EID',how='left')
# Out:
#         EID ENAME GENDER  PAYMENT_DY PAYMENT_DVCD  PAYMENT_AMOUNT
# 0    E00206   시이오      M  20240401.0           월급           850.0
# 1    E00206   시이오      M  20240401.0          성과급           425.0
# 2    E00206   시이오      M  20240401.0          상여금           300.0
# 3    E00206   시이오      M  20240501.0           월급           850.0
# 4    E00206   시이오      M  20240601.0           월급           850.0
# ..      ...   ...    ...         ...          ...             ...
# 799  E00428   을충나      F  20240401.0           월급           375.0
# 800  E00428   을충나      F  20240401.0          성과급           188.0
# 801  E00428   을충나      F  20240401.0          상여금           300.0
# 802  E00428   을충나      F  20240501.0           월급           375.0
# 803  E00428   을충나      F  20240601.0           월급           375.0
#
# [804 rows x 6 columns]

# %%
# 병합 오른똑 DF 를 기준으로 병합 =0--> result_right

# %%
pd.merge(hr_df,hr_pay,on='EID',how='right')
# Out:
#         EID ENAME GENDER  PAYMENT_DY PAYMENT_DVCD  PAYMENT_AMOUNT
# 0    E00206   시이오      M    20240401           월급             850
# 1    E00181   나사장      F    20240401           월급             791
# 2    E00164  난부사장      M    20240401           월급             758
# 3    E00190   판라다      F    20240401           월급             708
# 4    E00209   누훈봉      M    20240401           월급             716
# ..      ...   ...    ...         ...          ...             ...
# 750  E00322   부탐회      F    20240601           월급             375
# 751  E00389   초두반      F    20240601           월급             375
# 752  E00438   권개득      M    20240601           월급             375
# 753  E00304   탐출조      M    20240601           월급             375
# 754  E00428   을충나      F    20240601           월급             375
#
# [755 rows x 6 columns]

# %% [markdown]
# ### 정리
# - hr_df,hr_pay
# - leftjoin : 조직 구성원 목록을 기준으로 병합, 급여 정보가 없는 구성원도 포함
# - Rightjoin : 급여 지급 데이터 기준으로 병합 , 급여 정보가 없는 구성원은 제외
# - 조인 방신은 분석목적에 따라 다르게 선택
# - 구성원 전체를 유지 left ,급여내역중심 정리 right

# %% [markdown]
# ### 데이터 삭제
# - df.drop('삭제하고자하는 인덱스명 or 컬럼명 ')
# - 행 삭제 -> 0 열 삭제 -> 1
# - defult = 0

# %%
hr.drop('NATION',axis=1)
# Out:
#         EID ENAME GENDER  ORG_CD POS_CD  AGE  SERVICE_YEAR EDU_LEVEL  \
# 0    E00206   시이오      M     NaN   P001   49            25     박사 학위
# 1    E00181   나사장      F     NaN   P002   49            24     박사 학위
# 2    E00164  난부사장      M     NaN   P003   48            22     박사 학위
# 3    E00190   판라다      F  ORG007   P004   47            18     박사 학위
# 4    E00209   누훈봉      M  ORG023   P004   47            19     박사 학위
# ..      ...   ...    ...     ...    ...  ...           ...       ...
# 195  E00322   부탐회      F  ORG014   P009   23             0     학사 학위
# 196  E00389   초두반      F  ORG012   P009   23             0     학사 학위
# 197  E00438   권개득      M  ORG024   P009   23             0     학사 학위
# 198  E00304   탐출조      M  ORG009   P009   24             0     학사 학위
# 199  E00428   을충나      F  ORG003   P009   24             0     학사 학위
#
#      PERFORMANCE_SCORE  SALARY LAST_PROMO_DT  TRAINING_HOURS  \
# 0                 4.50   10200    2024-03-01             240
# ...

# %%
#데이터의 무분별한 삭제를 방지하기위해 다시한번 확인하는 속성 존재 
hr
# Out:
#         EID ENAME GENDER  ORG_CD POS_CD  AGE  SERVICE_YEAR EDU_LEVEL  \
# 0    E00206   시이오      M     NaN   P001   49            25     박사 학위
# 1    E00181   나사장      F     NaN   P002   49            24     박사 학위
# 2    E00164  난부사장      M     NaN   P003   48            22     박사 학위
# 3    E00190   판라다      F  ORG007   P004   47            18     박사 학위
# 4    E00209   누훈봉      M  ORG023   P004   47            19     박사 학위
# ..      ...   ...    ...     ...    ...  ...           ...       ...
# 195  E00322   부탐회      F  ORG014   P009   23             0     학사 학위
# 196  E00389   초두반      F  ORG012   P009   23             0     학사 학위
# 197  E00438   권개득      M  ORG024   P009   23             0     학사 학위
# 198  E00304   탐출조      M  ORG009   P009   24             0     학사 학위
# 199  E00428   을충나      F  ORG003   P009   24             0     학사 학위
#
#      PERFORMANCE_SCORE  SALARY LAST_PROMO_DT  TRAINING_HOURS  \
# 0                 4.50   10200    2024-03-01             240
# ...

# %%
#inplace 속성
hr.drop('TRAINING_HOURS',axis=1,inplace=True)

# %%
hr
# Out:
#         EID ENAME GENDER  ORG_CD POS_CD  AGE  SERVICE_YEAR EDU_LEVEL  \
# 0    E00206   시이오      M     NaN   P001   49            25     박사 학위
# 1    E00181   나사장      F     NaN   P002   49            24     박사 학위
# 2    E00164  난부사장      M     NaN   P003   48            22     박사 학위
# 3    E00190   판라다      F  ORG007   P004   47            18     박사 학위
# 4    E00209   누훈봉      M  ORG023   P004   47            19     박사 학위
# ..      ...   ...    ...     ...    ...  ...           ...       ...
# 195  E00322   부탐회      F  ORG014   P009   23             0     학사 학위
# 196  E00389   초두반      F  ORG012   P009   23             0     학사 학위
# 197  E00438   권개득      M  ORG024   P009   23             0     학사 학위
# 198  E00304   탐출조      M  ORG009   P009   24             0     학사 학위
# 199  E00428   을충나      F  ORG003   P009   24             0     학사 학위
#
#      PERFORMANCE_SCORE  SALARY LAST_PROMO_DT  \
# 0                 4.50   10200    2024-03-01
# ...

# %% [markdown]
# ### apply
# - DF,Series 데이터를 함수를 행or 열 단위로 적용할때 사용
# - df.apply(함수,축설정)-> 기본축은 행우선

# %%
# 년-월-일 로 구성되어있는 데이터에서 연도 데이터만 추출
date_list = [{'yyyy-mm-dd': '2003-03-13'},
            {'yyyy-mm-dd': '2017-10-20'},
            {'yyyy-mm-dd': '2022-05-28'}]
date_df = pd.DataFrame(date_list, columns=['yyyy-mm-dd'])
date_df
# Out:
#    yyyy-mm-dd
# 0  2003-03-13
# 1  2017-10-20
# 2  2022-05-28

# %%
data='2003-03-13'
data
# Out:
# '2003-03-13'

# %%
# 특정 기호 중신 문자열 분리  -> 리스트
data.split('-')[0]
# Out:
# '2003'

# %%
# 사용자 정의 함수 생성
def extract_year (data):
    return data.split('-')[0]

# %%
date_df['year']=date_df['yyyy-mm-dd'].apply(extract_year)

# %%
date_df
# Out:
#    yyyy-mm-dd  year
# 0  2003-03-13  2003
# 1  2017-10-20  2017
# 2  2022-05-28  2022

# %%
date_df['yyyy-mm-dd'].str.split('-')
# Out:
# ['2003', '03', '13']

# %% [markdown]
# ### apply 적용 실습
# - 내용 : 직원의 성과점수 PERFORMANCE_SCORE 기준으로 성과 등급 PERFORMANCE_GRADE 컬럼 새로 생성
# - 조건
#   - 사용자 정의 함수 :'get_grade'선언후 적용
# | 성과 점수 | 성과 등급 |
# |----------|----------|
# | 4.5 이상 | S |
# | 4.0 이상 | A |
# | 3.0 이상 | B |
# | 그 외 | C |

# %%
hr
# Out:
#         EID ENAME GENDER  ORG_CD POS_CD  AGE  SERVICE_YEAR EDU_LEVEL  \
# 0    E00206   시이오      M     NaN   P001   49            25     박사 학위
# 1    E00181   나사장      F     NaN   P002   49            24     박사 학위
# 2    E00164  난부사장      M     NaN   P003   48            22     박사 학위
# 3    E00190   판라다      F  ORG007   P004   47            18     박사 학위
# 4    E00209   누훈봉      M  ORG023   P004   47            19     박사 학위
# ..      ...   ...    ...     ...    ...  ...           ...       ...
# 195  E00322   부탐회      F  ORG014   P009   23             0     학사 학위
# 196  E00389   초두반      F  ORG012   P009   23             0     학사 학위
# 197  E00438   권개득      M  ORG024   P009   23             0     학사 학위
# 198  E00304   탐출조      M  ORG009   P009   24             0     학사 학위
# 199  E00428   을충나      F  ORG003   P009   24             0     학사 학위
#
#      PERFORMANCE_SCORE  SALARY LAST_PROMO_DT  \
# 0                 4.50   10200    2024-03-01
# ...

# %%
def get_grade (data):
    if data >=4.5:
        result='A'
    elif data>=4.0:
        result='A'
    elif data>=3.0:
        result='B'
    else :
        result='C'
    return result

# %%
a=hr['PERFORMANCE_SCORE'].apply(get_grade)

# %%
hr.insert(loc =9,column= 'PERFORMANCE_GRADE',value =a)

# %%
hr
# Out:
#         EID ENAME GENDER  ORG_CD POS_CD  AGE  SERVICE_YEAR EDU_LEVEL  \
# 0    E00206   시이오      M     NaN   P001   49            25     박사 학위
# 1    E00181   나사장      F     NaN   P002   49            24     박사 학위
# 2    E00164  난부사장      M     NaN   P003   48            22     박사 학위
# 3    E00190   판라다      F  ORG007   P004   47            18     박사 학위
# 4    E00209   누훈봉      M  ORG023   P004   47            19     박사 학위
# ..      ...   ...    ...     ...    ...  ...           ...       ...
# 195  E00322   부탐회      F  ORG014   P009   23             0     학사 학위
# 196  E00389   초두반      F  ORG012   P009   23             0     학사 학위
# 197  E00438   권개득      M  ORG024   P009   23             0     학사 학위
# 198  E00304   탐출조      M  ORG009   P009   24             0     학사 학위
# 199  E00428   을충나      F  ORG003   P009   24             0     학사 학위
#
#      PERFORMANCE_SCORE PERFORMANCE_GRADE  SALARY LAST_PROMO_DT  \
# 0                 4.50                 A   10200    2024-03-01
# ...
