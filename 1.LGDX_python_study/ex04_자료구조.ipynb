# %% [markdown]
# ![image.png](attachment:d9add1c7-5270-45dc-a92a-a258e92409c8.png)

# %% [markdown]
# ![image.png](attachment:a720b850-620f-4cfe-b2ef-c0bd3dbfd850.png)

# %%
print("*****************************************")
lst=["딸기","바나나","수박","체리","포도"]
s=input("검색할 문자 입력 >")
if s in lst:
    print(f"{s}는 리스트에 {lst.index(s)+1}번째 인덱스에 들어있습니다")
else :
    print(f"{s}는 리스트에 들어있지 않습니다")
print("*****************************************")
# Out:
# *****************************************
# 검색할 문자 입력 > 딸기
# 딸기는 리스트에 1번째 인덱스에 들어있습니다
# *****************************************

# %% [markdown]
# ![image.png](attachment:4cc6918c-da6f-4588-b1d9-e743073cd8d6.png)

# %%
se="Hi, My name is Mihee"
print("*****************************************")
s=input("검색할 문자 입력 >")
if s in se:
    print(f"{s}'는 {se.count(s)}번 들어있습니다")
else:
     print(f"{s}는 문자열 에 들어있지 않습니다")
print("*****************************************")
# Out:
# *****************************************
# 검색할 문자 입력 > 지지용
# 지지용는 문자열 에 들어있지 않습니다
# *****************************************

# %% [markdown]
# ![image.png](attachment:960d82b4-a320-46f9-b0bb-41d99f1762f2.png)

# %%
menu=[]
print("요리 3가지 입력")
menu_1=input("첫번째 메뉴 입력 >> ")
menu.append(menu_1)
menu_1=input("두번째 메뉴 입력 >> ")
menu.append(menu_1)
menu_1=input("세번째 메뉴 입력 >> ")
menu.append(menu_1)
print(f"주문하신메뉴는 {menu[0]},{menu[1]},{menu[2]} 입니다")
menu_1=input("마지막메뉴를 바꾸시겟습니까? 뭘롱 바꿀랭 ")
menu.pop()
menu.append(menu_1)
print(f"다시확인할게요 .주문하신 메뉴는  {menu[0]},{menu[1]},{menu[2]} 입니다")
# Out:
# 요리 3가지 입력
# 첫번째 메뉴 입력 >>  탕수육
# 두번째 메뉴 입력 >>  가지튀김
# 세번째 메뉴 입력 >>  짬뽕
# 주문하신메뉴는 탕수육,가지튀김,짬뽕 입니다
# 마지막메뉴를 바꾸시겟습니까?  간짜장
# 다시확인할게요 .주문하신 메뉴는  탕수육,가지튀김,간짜장 입니다
