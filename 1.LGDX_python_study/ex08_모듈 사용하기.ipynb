# %% [markdown]
# ### 학습목표
# - 사용자 정의 함수를 파일로 저장하여 다른 파일에서 불러와 사용할수있다

# %% [markdown]
# ![image.png](attachment:423d91e0-8a82-4521-8d0e-19b5caa04e92.png)

# %%
import Module

# %%
Module.add_num(1,3)
# Out:
# 4

# %%
Module.sub_num(1,3)
# Out:
# -2

# %%
import Module as md

# %%
md.add_num(1,3)
# Out:
# 4

# %%
md.sub_num(1,3)
# Out:
# -2

# %%
from Module import add_num

# %%
add_num(1,3)
# Out:
# 4

# %%
import numpy as np
import pandas as pd
