# %%
from tqdm import tqdm
import pandas as pd
import requests as req 
from bs4 import BeautifulSoup as bs
import re
from kiwipiepy import Kiwi
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt
# 컴퓨터용 브라우저 -> 데이터 요청 및 응답 
from selenium import webdriver as wb
# 컴퓨터용 키보드 (Enter,Del 등 ) 컴퓨터에게 키보드를 전달하는 역할 
from selenium.webdriver.common.keys import Keys 
# 선택자를 구분할때 사용하는 라이브러리 (필수)
from selenium.webdriver.common.by import By
#쉬는 시간을 주는 라이브러리 
import time
#mask 이미지를 만들기 위한 도구
from PIL import Image
import numpy as np
# 글(문자열등) 데이터가 url에 들어갓을때 띄어쓰기가 있으면 오류 발생
# url 글이 들어갔을떄 안전하게 사용하수있는 혀애로 변경해주는 기능 
from urllib.parse import quote

# %%
url='https://s.chosun.ac.kr/'

# %%
driver = wb.Chrome()
driver.get(url)

# %%
driver.switch_to.frame('myFrame')

# %%
driver.find_elements(By.CSS_SELECTOR,'#loginBtn')[0].click()

# %%
search=driver.find_element(By.CSS_SELECTOR,'#uuid-f > div:nth-child(1) > input')
search.send_keys('20203109')

# %%
search=driver.find_element(By.CSS_SELECTOR,'#uuid-g > div:nth-child(1) > input')
search.send_keys('Jyc6863972!')
search.send_keys(Keys.ENTER)

# %%
#uuid-i > a > div     uuid-1aj
driver.find_elements(By.CSS_SELECTOR,'#uuid-9w > div > div > div:nth-child(3) > div > div.cl-grid-detail.cl-grid-detail-band > div > div:nth-child(1) > div > div > div:nth-child(1) > div:nth-child(2) > div > div > div')
# Out:
# []

# %%
#신청완료
driver.find_elements(By.CSS_SELECTOR,'#uuid-9w > div > div > div:nth-child(3) > div > div.cl-grid-detail.cl-grid-detail-band > div > div:nth-child(1) > div > div > div:nth-child(1) > div:nth-child(2) > div')
# Out:
# []

# %%
#신청닫기 
driver.find_elements(By.CSS_SELECTOR,'.btn-02.cl-control.cl-button.cl-unselectable.popup-btn')[0].click()

# %%
#uuid-1e > div > div > div:nth-child(3) > div > div.cl-grid-detail.cl-grid-detail-band > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 driver.find_elements(By.CSS_SELECTOR,'uuid-i > a > div')[0].click()
#
# IndexError: list index out of range

# %%
driver.find_elements(By.CSS_SELECTOR,'#uuid-1e > div > div > div:nth-child(3) > div > div.cl-grid-detail.cl-grid-detail-band > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div')[0].click()

# %%
#uuid-1e > div > div > div:nth-child(3) > div > div.cl-grid-detail.cl-grid-detail-band > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div > div > div
