# %%
from tqdm import tqdm
import pandas as pd
import requests as req 
from bs4 import BeautifulSoup as bs
import re
from kiwipiepy import Kiwi
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt

# %%
def preprocess_sentence_kr(w):
  w = w.strip()
  w = re.sub(r"[^0-9가-힣?.!,¿]+", " ", w) 
  w = w.strip() 
  return w

# %%
url='https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&ssc=tab.nx.all&query=%EC%95%84%EB%B0%94%ED%83%803+%EB%A6%AC%EB%B7%B0&oquery=%EC%95%84%EB%B0%94%ED%83%802+%EB%A6%AC%EB%B7%B0&tqi=jUsNTwqos5ossi2ZKPZ-342894&ackey=74e97f8t'
print(req.get(url))
new=req.get(url)
chart= bs(new.text,'lxml')
ur=chart.select(".list_title>a")
blog_url=[]
blog_title=[]
blog_content=[]
total=[]
f=open('../../data/movie_review.txt','w',encoding='utf-8')
for i in tqdm(range(len(ur))):
    tmp_link=ur[i].get('href')
    new=req.get(tmp_link)
    soup1= bs(new.text,'lxml')
    a=soup1.select_one('#mainFrame').get('src')
    tmp='https://blog.naver.com/'+a
    blog_url.append(tmp)
    new=req.get(blog_url[i])
    soup2= bs(new.text,'lxml')
    blog_title.append(soup2.select_one('.se-module.se-module-text.se-title-text>p>span').text)
    blog_content.append(preprocess_sentence_kr(soup2.select('.se-main-container')[0].text))
    total.append([blog_url[i],blog_title[i],blog_content[i]])
    f.write(preprocess_sentence_kr(soup2.select('.se-main-container')[0].text))
f.close()
# Out:
# <Response [200]>
# 100%|██████████| 10/10 [00:14<00:00,  1.46s/it]

# %%
blog_url
# Out:
# ['https://blog.naver.com//PostView.naver?blogId=syunni1225&logNo=224115606045&redirect=Dlog&widgetTypeCall=true&noTrackingCode=true&directAccess=false',
#  'https://blog.naver.com//PostView.naver?blogId=kaminari2002&logNo=224114898643&redirect=Dlog&widgetTypeCall=true&noTrackingCode=true&directAccess=false',
#  'https://blog.naver.com//PostView.naver?blogId=seok9c&logNo=224115025215&redirect=Dlog&widgetTypeCall=true&noTrackingCode=true&directAccess=false',
#  'https://blog.naver.com//PostView.naver?blogId=duswns202&logNo=224106859517&redirect=Dlog&widgetTypeCall=true&noTrackingCode=true&directAccess=false',
#  'https://blog.naver.com//PostView.naver?blogId=dudghkrkwhgdms&logNo=224115758710&redirect=Dlog&widgetTypeCall=true&noTrackingCode=true&directAccess=false',
#  'https://blog.naver.com//PostView.naver?blogId=blac_beat&logNo=224128473123&redirect=Dlog&widgetTypeCall=true&noTrackingCode=true&directAccess=false',
#  'https://blog.naver.com//PostView.naver?blogId=realnogun&logNo=224113577463&redirect=Dlog&widgetTypeCall=true&noTrackingCode=true&directAccess=false',
#  'https://blog.naver.com//PostView.naver?blogId=c106507&logNo=224111497322&redirect=Dlog&widgetTypeCall=true&noTrackingCode=true&directAccess=false',
#  'https://blog.naver.com//PostView.naver?blogId=sta-tio&logNo=224114494844&redirect=Dlog&widgetTypeCall=true&noTrackingCode=true&directAccess=false',
#  'https://blog.naver.com//PostView.naver?blogId=stmisn&logNo=224091045516&redirect=Dlog&widgetTypeCall=true&noTrackingCode=true&directAccess=false']

# %%
total=pd.DataFrame(total,columns=['주소','리뷰이름','리뷰내용'])

# %%
total
# Out:
#                                                   주소  \
# 0  https://blog.naver.com//PostView.naver?blogId=...
# 1  https://blog.naver.com//PostView.naver?blogId=...
# 2  https://blog.naver.com//PostView.naver?blogId=...
# 3  https://blog.naver.com//PostView.naver?blogId=...
# 4  https://blog.naver.com//PostView.naver?blogId=...
# 5  https://blog.naver.com//PostView.naver?blogId=...
# 6  https://blog.naver.com//PostView.naver?blogId=...
# 7  https://blog.naver.com//PostView.naver?blogId=...
# 8  https://blog.naver.com//PostView.naver?blogId=...
# 9  https://blog.naver.com//PostView.naver?blogId=...
#
#                                                 리뷰이름  \
# 0  아바타: 불과 재(Avatar: Fire and Ash, 2025) 영화 정보, 리...
# 1  <아바타3: 불과 재> 4Dx3D후기 :: 그래도 극장에서 봐야하는 영화. 2편의 ...
# 2               사실상 아바타 2.5가 아니었나, 영화 <아바타: 불과 재> 후기
# 3              영화 아바타 불과 재 12세 관람가 러닝타임 등급 심사표 공개 수위
# 4                          아바타 3 불과 재 쿠키 영상 정보 영화 리뷰
# 5                영화 아바타3: 불과 재(2025) 정보, 줄거리, 결말, 후기
# 6                         영화 아바타 3편 불과 재 줄거리 결말 쿠키없음
# 7                       아바타 불과재 출격! 12월 셋째주 개봉 예정 영화
# 8  [영화 리뷰] 아바타: 불과 재 (2025년) 감상평과 후기, 영화 정보 / 분노와...
# 9          영화 '아바타: 불과 재' 시사회 초청 이벤트, KT 멤버십 X 롯데시네마
#
#                                                 리뷰내용
# 0  영화 아바타 불과 재 정보, 줄거리, 리뷰 영화 정보 기본 정보 원제 수입 배급 월...
# 1  영화 아바타 불과 재 를 4 3 로 관람했습니다. 2022년 아바타2 물의 길 이 ...
# 2  이번에도 기대 이상의 시각효과를 보여줌역대급 스케일의 전쟁과 전투 장면전편의 갈등 ...
# 3  아바타 불과 재 , 액션, 모험2025제임스 카메론 등급 심사 표는 관점에 따라 스...
# 4  오늘은 인생 영화 추천작 아바타 불과 재 쿠키 영상 정보를 포함한 리뷰 관람평을 작...
# 5  아바타 불과 재 , 액션, 모험2025제임스 카메론 제목 아바타 불과 재개봉 연도 ...
# 6  아바타 불과 재 , 액션, 모험2025제임스 카메론 대세는 하이브리드. 영화 아바타...
# 7  오늘은 2025년 51주차 12월 15일 21일 국내 박스오피스 개봉 예정 영화들을...
# 8  안녕하세요. 영화 인플루언서 스타티오 입니다. 오늘은 아바타 시리즈의 세 번째 영화...
# 9  올 12월도, 하반기도, 4분기도 아닌, 2025년의 기대작이라는 타이틀이 뒤따르고...

# %%
f=open('../../data/movie_review.txt','r',encoding='utf-8')

# %%
review=f.readline()
f.close()

# %%
review
# Out:
# '영화 아바타 불과 재 정보, 줄거리, 리뷰 영화 정보 기본 정보 원제 수입 배급 월트디즈니 컴퍼니 코리아감독 제임스 카메론출연 샘 워싱턴, 조이 살다나, 시고니 위버, 스티븐 랭, 우나 채플린, 케이트 윈슬렛 외제작 국가 미국장르 액션, 어드벤처 모험 , 판타지, , 스릴러관람 등급 12세 이상 관람가상영 시간 195분극장 개봉 2025년 12월 17일 줄거리 큰아들을 잃은 제이크 설리와 네이티리 가족은 저마다 애도를 하고 있다. 그러던 중 그들 가족에게 다시 위기가 찾아오는데... 리뷰로 보는 관람 포인트 여전히 말 안 듣는 아이들 3편을 보기 위해 굳이 2편을 복습하지 않아도 될 것 같아 일단 보기 시작한 영화 오프닝에서는 전편에서 사망한 네테이얌이 등장해 로아크와 자유롭게 비행을 하는 모습을 보여줬다. 나비족만이 할 수 있는 의식 같은 걸로 로아크는 죽은 형과 대화하며 즐거운 시간을 보낼 수 있던 것이었다.로아크가 자신만의 방식으로 형을 그리워하고 있을 때 엄마인 네이티리는 상실감에 아무것도 하지 못하고 슬퍼하기만 했다. 그리고 설리는 인간이 다시금 공격을 해올 걸 예상해 바다에 가라앉은 인간들의 전함에서 총을 비롯한 각종 무기를 모으기 시작했다. 설리네 가족이 의지하고 있는 멧카이나의 부족장은 강하게 반발했지만 설리는 뜻을 굽히지 않았다. 그러던 중에 제이크는 인간인 스파이더를 바람 상인의 편에 보내려고 했다. 스파이더가 쿼리치의 아들이었기에 데리고 있으면 그가 언제든 다시 공격해올 수 있었기 때문이었다. 스파이더는 강하게 반발했고, 설리의 아이들까지도 가족이라며 보내면 안 된다고 했지만 부모의 뜻을 꺾을 수는 없었다. 그나마 함께 가서 데려다주고 오자는 의견으로 분위기가 조금 누그러졌다. 바람 상인과 함께 떠나게 된 설리의 가족은 시작부터 불안불안하기만 했다. 이 사건 이전에 스파이더가 자던 중에 마스크에 문제가 생겨 죽을 뻔했었고, 설리가 로아크에게 무전기를 차야 한다고 했던 적이 있었다. 하지만 이 두 아이들은 당연히 말을 안 들었다. 전편에서 말 안 듣는 아이들 때문에 짜증 났던 기억이 남아 있는데, 이번에도 그러니 어처구니가 없었다. 네테이얌이 죽고서도 정신을 못 차렸다 싶었기 때문이다.이후 영화 후반으로 가면서 키리 역시 형제들이 말리는 데도 자신의 뜻대로 행동했고 막내 투크도 그랬다. 그리고 멧카이나 부족장의 딸 츠레이야 역시 후반에 자기 엄마에게 강하게 반발하는 등의 모습을 보였다. 그렇게 행동해야만 하는 이유가 있었지만, 말 안 듣는 애들을 워낙 끔찍해하는 나로서는 머리가 아플 지경이었다. 우당탕탕 설리네 가족 설리 가족이 바람 상인과 함께 가던 중에 망콴족이 나타나 공격을 시작했고, 쿼리치는 제이크를 또 잡겠다며 나타났다. 그로 인해 한바탕 전쟁이 벌어져 자랑이라도 하려는 듯 뛰어난 효과를 보여줬다. 일반 상영관에서 봤음에도 가 좋다는 건 알 수 있었다. 하지만 한 가지 의아했던 건 가 버벅거린다는 느낌이 드는 장면이 종종 있었다는 것이다. 망콴족 때문에 말 안 듣는 아이들은 자기들끼리 도망을 쳐야 했고 네이티리는 망콴족의 부족장 바랑이 쏜 활에 크게 다치고 말았다. 그리고 제이크는 쿼리치에게 붙잡히고 말았다. 제이크는 아이들이 무전기도 차지 않았고 스파이더의 마스크도 버려져 있는 걸 보고는 쿼리치에게 아이들을 먼저 구해야 한다고 말했다. 쿼리치는 제 아들에게 의외로 약했던 터라 얼마 동안 손을 잡고 아이들의 행적을 쫓기 시작했다.하지만 목표를 달성한 후에 제이크와 쿼리치는 다시 적으로 돌아갈 수밖에 없었다. 그로 인해 적의 적인 망콴의 바랑과 쿼리치가 손을 잡게 된 건 당연했다. 범죄도시 시리즈를 보는 듯한 감흥 사실 나는 2편도 재미있게 보질 않았다. 3 아이맥스로 봤고 기술력에 감탄하긴 했지만 그게 끝이었다. 영화를 영상미나 로만 보는 게 아닌 사람이라 별 내용이 없음에도 굳이 러닝타임이 3시간이 넘어야 하는지 의문스러웠다. 영화 전개를 위해 어쩔 수 없다 해도 말 안 듣는 아이들로 인해 사건 사고의 연속이라는 점 또한 마음에 들지 않았다.그래서 3편은 굳이 특별관에서 안 봐도 될 거라 생각해 일반 상영관에서 봤고, 가 버벅거릴 때가 있긴 했으나 일반 상영관 스크린으로도 기술력이 뛰어나다는 건 인정이었다. 하지만 역시나 이 이야기를 또 3시간이 넘게 해야 하는지는 회의적이었다. 가족이 죽었는데도 아이들은 여전히 말을 안 들었고, 쿼리치는 전생의 원수라도 되는지 제이크를 포기하질 않았다. 또한 자연과 공생하는 나비족은 선하고 생명체와 자연을 파괴하는 인간은 나쁘다는 의미 또한 전편과 같았다. 물론 도움을 주는 착한 인간이 있었고, 제이크의 가족을 공격하는 망콴족 같은 악당으로 변화를 주긴 했지만 전체적으로 비슷하다는 인상을 지울 수 없었다.그로 인해 영화를 보는 내내 3편을 보는 건지, 2편을 보는 건지 큰 차이가 없다 여겨졌다. 잘라내도 되는 장면이 꽤 있어서 그것만 덜어냈다면 그래도 지금보다는 나았을 텐데, 아쉽게도 좋아하는 영화를 보는 일에 피로감을 느끼고 말았다. 영화를 보며 떠올린 건 범죄도시 시리즈와 아바타 시리즈가 무슨 차이가 있냐는 것이다. 주먹으로 승부하는 형사 마석도가 범죄자를 소탕하는 범죄도시 , 시각적인 즐거움으로 현실에 존재하지 않는 세계에 대해 말하는 아바타 는 내게 큰 차이가 없었다. 시리즈가 전체적으로 패턴화된 것 역시 똑같았기에 전혀 흥미롭지 않았다.그리고 이번 영화에서 가장 아쉬웠던 건 여러 사건을 데우스 엑스 마키나 적으로 해결한 것이었다. 그 중심에 선 키리가 스파이더의 일을 비롯해 마지막 전투까지 다 해결하는 걸 보며 아바타 세계관의 신은 에이와가 아니라 키리인지도 모른다는 생각을 했다. 대부분의 사람들이 12월 최고 기대작으로 뽑았지만 나는 전혀 기대하지 않았던 아바타 불과 재 는 역시나 기대하지 않은 만큼의 인상을 남겼다. 여전한 캐릭터들과 사건 사고의 연속, 그러고선 결말엔 선한 자가 이기는 흐름을 뛰어난 로 덮어버리고 있었다. 영화는 시각적 효과보다 내용이 중요하다 여기는 내게는 아쉽기만 한 영화였지만, 오락 영화를 좋아하는 사람이라면 즐겁게 볼 것 같다.4편이 나올지 안 나올지 모르겠지만, 나온다면 이제 극장에서는 안 보지 않을까 싶다. 덧. 영화 상영 전에 나온 어벤져스 둠스데이 예고편 볼 때 제일 심장이 뛰었음. 아바타 불과 재 , 액션, 모험2025제임스 카메론영화 아바타 불과 재 를 4 3 로 관람했습니다. 2022년 아바타2 물의 길 이 개봉하고 3년만에 개봉한 시리즈 3편입니다. 이번에도 1000만 관객동원이 가능할까 귀추가 주목되고있는데, 현재로는 2편보다 국내 초반 흥행추이가 좀 떨어지는 편인데 장기흥행으로 어떨지 모르겠고, 평가도 이전보단 조금 약한 편이네요. 롯데시네마 월드타워 에서 관람. 아바타3 은 재의 부족 을 새롭게 등장시켰습니다.분노의 불과 슬픔의 재를 바탕으로 이루어진 과격하고 폭력적인 부족이라 할 수 있겠는데,2편 물의 길 이 물 이라는 소재를 강조했다면,3편 불과 재 에선 불 이라는 소재와 이미지를 강조한 작품이라 할 수 있겠네요. 3편 역시 러닝타임이 길어 197분으로 3시간이 훌쩍 넘는데, 제임스 카메론 감독 영화답게 재미는 있어 화장실 한번 안가고 3시간동안 재밌게 봤는데요.그래도 2편보다 아쉬움이 조금 남는 3편이긴 했습니다. 기술력은 발전해.이야기는 반복해. 그 큰 이유로는 반복되는 이야기 구조 때문인 것 같았는데요. 새로운 부족이 등장하긴했지만, 이야기 전개가 2편과 판박이처럼 전개되거나, 도돌이표처럼 본 걸 약간 또 보고있는 느낌?인 것 같더군요. 2,3편을 동시촬영했다고는 하지만.. 2편에서 어느정도 다 싸운 것 같았는데, 쿼리치 대령과 제이크 설리 가족이 스파이더 를 두고 또 싸우고있는 것 같았고, 그 때문에 여러 부족을 또 공격하고 대립하고 이 패턴이 반복되고있는 것 같았고.. 심지어 몇장면은 어, 이 장면 2편에서 본 것 같았는데? 하는 기시감이 자주 들더군요. 그나마 3편에서 큰 변주를 준 건 스파이더 캐릭터를 2편보다 더 적극활용하여, 중요한 요소로 급부상시켜 변수로 작용시켰고 변화를 줬다는 점 이었습니다. 쿼리치 대령의 아들이지만, 설리 가족과 함께 살았고, 3편에선 더 많은 여러가지 변화를 ...

# %% [markdown]
# - 형태소 분석기를 활용하여 문서 -> 토큰화 -> 단어 단위로 변경
#  - 키위 형태소 분석기 사용

# %%
# !pip install kiwipiey
# Out:
# Requirement already satisfied: kiwipiepy in c:\users\jyc68\anaconda3\lib\site-packages (0.22.2)
# Requirement already satisfied: kiwipiepy_model<0.23,>=0.22 in c:\users\jyc68\anaconda3\lib\site-packages (from kiwipiepy) (0.22.1)
# Requirement already satisfied: numpy in c:\users\jyc68\anaconda3\lib\site-packages (from kiwipiepy) (2.3.5)
# Requirement already satisfied: tqdm in c:\users\jyc68\anaconda3\lib\site-packages (from kiwipiepy) (4.67.1)
# Requirement already satisfied: colorama in c:\users\jyc68\anaconda3\lib\site-packages (from tqdm->kiwipiepy) (0.4.6)

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\jyc68\anaconda3\lib\site-packages (1.9.5)
# Requirement already satisfied: numpy>=1.19 in c:\users\jyc68\anaconda3\lib\site-packages (from wordcloud) (2.3.5)
# Requirement already satisfied: pillow in c:\users\jyc68\anaconda3\lib\site-packages (from wordcloud) (12.0.0)
# Requirement already satisfied: matplotlib in c:\users\jyc68\anaconda3\lib\site-packages (from wordcloud) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jyc68\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jyc68\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jyc68\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jyc68\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\jyc68\anaconda3\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jyc68\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jyc68\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\jyc68\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
