# %% [markdown]
# ### 네이버 뉴스데이터 수집
# - 실습 프로세스
#    1. 네이버 뉴스 페이지 접속 -> IT/과학 카테고라
#    2. 헤드라인 뉴스 접근
#    3. 뉴스의 제목,내용 수집

# %%
import requests as req 
from bs4 import BeautifulSoup as bs

# %%
url='https://n.news.naver.com/mnews/article/366/0001136987'

# %%
#뉴스 제목 추출
new=req.get(url)

# %%
url='https://n.news.naver.com/mnews/article/366/0001136987'
news= bs(new.text,'lxml')
title=news.select_one("h2.media_end_head_headline>span")
#풀이

# %%
title=news.select_one("h2.media_end_head_headline>span")
#풀이

# %%
print(title.text)
# Out:
# 과기정통부, 정부 연구개발 18개 기관과 예산 집행 ‘합동 설명회’ 개최

# %%
#풀이 
news.select_one("#title_area>span") # 아이디 값으로 가져오기
# Out:
# <span>과기정통부, 정부 연구개발 18개 기관과 예산 집행 ‘합동 설명회’ 개최</span>

# %%
#뉴스 내용 추출

# %%
news.select_one('article#dic_area').text.strip()
# Out:
# '과학기술정보통신부 현판./뉴스1        과학기술정보통신부(과기정통부)는 정부 연구개발(R&D) 사업을 수행하는 18개 중앙행정기관과 합동으로 설명회를 개최했다고 19일 밝혔다.과기정통부는 대전 한국과학기술원(카이스트) 대강당에서 이날부터 21일까지 ‘2026년도 정부 연구개발 사업 부처합동 설명회’를 열고 35조5000억원 규모로 책정된 올해 정부 연구개발 사업 내용을 설명한다. 예산은 인공지능(AI)·반도체·양자·첨단바이오·에너지·우주항공 등 미래 성장동력 분야를 비롯해 ▲기초연구 확대 ▲인재양성 강화 ▲지역 균형 발전 등 ‘연구생태계 강화’에 투입된다.올해 연구개발 정책은 33개 부·처·청에서 추진된다. 투자 규모로는 과기정통부·방사청·산업통상부·중소벤처기업부·기후에너지환경부·교육부·보건복지부·우주항공청 등의 순으로 높다. 과기정통부 측은 “산·학·연 연구자들이 각 부처의 정부 연구개발 사업들을 한자리에서 체계적으로 파악할 수 있도록 18개 부처가 합동으로 설명회를 개최하는 것”이라며 “설명회에는 약 3만명의 연구자·전문가가 온·오프라인으로 참여할 것으로 예상된다”고 전했다.이날 오전에는 과기정통부 과학기술혁신본부에서 2026년도 정부연구개발 예산의 주요 특징을 비롯해 ▲연구개발 생태계 혁신 방안 ▲예타 폐지 후속 제도 ▲연구비 자율성 확대 및 부정 사용 제재 조치 강화 등에 대해 설명했다. 오후에는 과기정통부·우주항공청·국토교통부가 각 부처 주요 연구개발 사업 내용 및 추진 일정 등을 발표한다.20일에는 교육부·중소벤처기업부·산업통상부·보건복지부·질병관리청·식품의약품안전처·소방청이, 21일에는 국방부·행정안전부·기후에너지환경부·해양수산부·농림축산식품부·농촌진흥청·산림청·문화체육관광부가 발표를 진행한다.박인규 과학기술혁신본부장은 “확대된 예산은 AI·에너지·전략 기술 등 기술 주도 성장에 집중 투입된다”며 “기초 연구 생태계를 복원하고 기업과 지역도 함께 성장하는 선순환 연구 생태계 조성도 함께 추진하고 있다”고 밝혔다. 그러면서 “연구 현장의 목소리를 반영해 PBS 단계적 폐지, 예타 제도 폐지 등의 제도 개선도 함께 추진하고 있다”고 덧붙였다.'

# %%
news_contents = news.select_one('.go_trans._article_content')
print(news_contents.text)
# Out:
# 과학기술정보통신부 현판./뉴스1        과학기술정보통신부(과기정통부)는 정부 연구개발(R&D) 사업을 수행하는 18개 중앙행정기관과 합동으로 설명회를 개최했다고 19일 밝혔다.과기정통부는 대전 한국과학기술원(카이스트) 대강당에서 이날부터 21일까지 ‘2026년도 정부 연구개발 사업 부처합동 설명회’를 열고 35조5000억원 규모로 책정된 올해 정부 연구개발 사업 내용을 설명한다. 예산은 인공지능(AI)·반도체·양자·첨단바이오·에너지·우주항공 등 미래 성장동력 분야를 비롯해 ▲기초연구 확대 ▲인재양성 강화 ▲지역 균형 발전 등 ‘연구생태계 강화’에 투입된다.올해 연구개발 정책은 33개 부·처·청에서 추진된다. 투자 규모로는 과기정통부·방사청·산업통상부·중소벤처기업부·기후에너지환경부·교육부·보건복지부·우주항공청 등의 순으로 높다. 과기정통부 측은 “산·학·연 연구자들이 각 부처의 정부 연구개발 사업들을 한자리에서 체계적으로 파악할 수 있도록 18개 부처가 합동으로 설명회를 개최하는 것”이라며 “설명회에는 약 3만명의 연구자·전문가가 온·오프라인으로 참여할 것으로 예상된다”고 전했다.이날 오전에는 과기정통부 과학기술혁신본부에서 2026년도 정부연구개발 예산의 주요 특징을 비롯해 ▲연구개발 생태계 혁신 방안 ▲예타 폐지 후속 제도 ▲연구비 자율성 확대 및 부정 사용 제재 조치 강화 등에 대해 설명했다. 오후에는 과기정통부·우주항공청·국토교통부가 각 부처 주요 연구개발 사업 내용 및 추진 일정 등을 발표한다.20일에는 교육부·중소벤처기업부·산업통상부·보건복지부·질병관리청·식품의약품안전처·소방청이, 21일에는 국방부·행정안전부·기후에너지환경부·해양수산부·농림축산식품부·농촌진흥청·산림청·문화체육관광부가 발표를 진행한다.박인규 과학기술혁신본부장은 “확대된 예산은 AI·에너지·전략 기술 등 기술 주도 성장에 집중 투입된다”며 “기초 연구 생태계를 복원하고 기업과 지역도 함께 성장하는 선순환 연구 생태계 조성도 함께 추진하고 있다”고 밝혔다. 그러면서 “연구 현장의 목소리를 반영해 PBS 단계적 폐지, 예타 제도 폐지 등의 제도 개선도 함께 추진하고 있다”고 덧붙였다.

# %% [markdown]
# ### 실습
# - 하나의 뉴스제목이 아닌 여러개의 다양한 뉴스 제목 수집
# 1. 페이지 정보 받아오기
# 2. 뉴스제목 수집하기(헤드라인 5 개 제목)
# 3. news_list 리스트에 뉴스 제목 담기

# %%
url2='https://news.naver.com/section/105'
new1=req.get(url2)
news1= bs(new1.text,'lxml')

# %%
news1.select(".sa_text_strong")
# Out:
# [<strong class="sa_text_strong">"뇌 훈련으로 면역 강화할 수 있다…백신 효과 향상 확인"[건강포커스]</strong>,
#  <strong class="sa_text_strong">SKT, '개인정보 유출' 과징금 1,300억 원 취소 소송 제기</strong>,
#  <strong class="sa_text_strong">"AI표시 어디까지 넣어야 하나요"…법안 곳곳이 그레이존</strong>,
#  <strong class="sa_text_strong">세계 첫 '탈원전' 국가도 돌아섰다…25년 만에 백기 든 이유 [강경주의 테크X]</strong>,
#  <strong class="sa_text_strong">아이폰18 프로, 다이내믹 아일랜드 어떻게 바뀔까</strong>,
#  <strong class="sa_text_strong">의료기기 삼총사 약진...그래피·리브스메드·WSI 급등[바이오맥짚기]</strong>,
#  <strong class="sa_text_strong">[100세 과학] 긍정적 생각, 백신 효과도 높인다</strong>,
#  <strong class="sa_text_strong">"쓰레기로 1700억 벌었다?"…유튜브만 열면 나온다 싶더니</strong>,
#  <strong class="sa_text_strong">인사팀·AI팀 빼고 다 자른다더니…오히려 일자리 늘어난 빅테크 왜</strong>,
#  <strong class="sa_text_strong">흑인 청년과 만난 한국 할머니의 넉살…벌써 1.4억뷰 넘었다는데</strong>,
#  <strong class="sa_text_strong">‘AI 트로트’ 천만 뷰 열풍…음악가들은 속이 타들어간다</strong>,
#  <strong class="sa_text_strong">"폰 색상은 '흑백''이 명불허전"…갤럭시 S26 울트라 어떻게 나올까</strong>,
#  <strong class="sa_text_strong">삼성 갤럭시, 中 패널 넣는다… '부품값 폭등' 정면 돌파</strong>,
#  <strong class="sa_text_strong">넷플릭스 1500만 보는데 토종 왓챠는 생존 위기</strong>,
#  <strong class="sa_text_strong">엔비디아가 29조 쓴 이유…AI 반도체 판 흔들린다</strong>,
#  <strong class="sa_text_strong">HBM 양산 앞둔 中… 반도체 장비 생태계 구축 ‘사활’</strong>,
#  <strong class="sa_text_strong">삼성전자·SK하이닉스, 올해 낸드플래시 생산량 감축… “초호황기 이익 극대화”</strong>,
#  <strong class="sa_text_strong">네카오, 2025년 합산 매출 20조…커머스·광고로 '역대 최대 실적'</strong>,
#  <strong class="sa_text_strong">대형 R&amp;D 착수, 평균 48개월→7개월로 줄인다</strong>,
#  <strong class="sa_text_strong">새벽 2시 베이징… ‘중국 AI 심장’은 계속 뛰고 있다</strong>,
#  <strong class="sa_text_strong">금값 된 칩값… 100만원 하던 PC가 170만원 됐다</strong>,
#  <strong class="sa_text_strong">뤄푸리·야오순위… 中 AI 이끄는 천재들</strong>,
#  <strong class="sa_text_strong">“국가대표 AI 1차전서 완벽한 승리”… LG AI 연구원, 뚝심 투자 빛 발해</strong>,
#  <strong class="sa_text_strong">“20만원 내려도 하루 1대도 안 팔려” 너무하다 했더니…특단 조치</strong>,
#  <strong class="sa_text_strong">아직 ‘솔로’인 당신, 부모와 함께 살거나 학력 높을수록 연애 못한다는데</strong>,
#  <strong class="sa_text_strong">네이버 탈락시킨 ‘프롬 스크래치’ 잣대··· 기술 효율보다 독자성 택한 과기부</strong>,
#  <strong class="sa_text_strong">"한국 기업은 누적 투자 평균 3회...미국은 8~10회"</strong>,
#  <strong class="sa_text_strong">“동네 사람이라 믿었는데” 돈만 받고 ‘당근’ 탈퇴…너무하다했더니, 초유의 결단</strong>,
#  <strong class="sa_text_strong">"업스테이지 논란, 韓 AI의 자정과 기술을 남겼다"[only이데일리]</strong>,
#  <strong class="sa_text_strong">미국, AI 핵심 메모리 칩 생산 사실상 '제로'... 관세로 동맹국 옥죄기</strong>,
#  <strong class="sa_text_strong">로봇 탄 현대차… 시총 100조 코 앞</strong>,
#  <strong class="sa_text_strong">먹방 이젠 식상하다 했는데…“결국 쯔양까지 투입했다” ‘70만명’ 이탈 사태에 ‘발칵’</strong>,
#  <strong class="sa_text_strong">신형 폰 가격 또 오른다니…'중고' 쓰는 소비자들</strong>,
#  <strong class="sa_text_strong">다보스포럼, 주요 그룹 총수 발길 뜸해진 이유</strong>,
#  <strong class="sa_text_strong">제미나이 1년 새 4배 성장…오픈AI ‘왕좌 사수’ 안간힘</strong>,
#  <strong class="sa_text_strong">빚내며 10년 버틴 의사과학자, '7500억원 기술이전' 빛 봤다</strong>,
#  <strong class="sa_text_strong">"100GB 100원" SKT 자급제 요금제 '에어' 써볼까</strong>,
#  <strong class="sa_text_strong">"광고 보면 구독료 반값"' 챗GPT가 불붙인 AI 저가요금제</strong>,
#  <strong class="sa_text_strong">“아들·딸보다 낫네”…어르신 안부 챙기는 ‘AI 전화’ [이슈픽]</strong>]

# %%
url2 = 'https://news.naver.com/section/105'
res2 = req.get(url2)
soup2 = bs(res2.text, 'lxml')
news_titles = soup2.select('.section_article.as_headline .sa_text_strong')

lst=[]

# %%
news_titles
# Out:
# [<strong class="sa_text_strong">"뇌 훈련으로 면역 강화할 수 있다…백신 효과 향상 확인"[건강포커스]</strong>,
#  <strong class="sa_text_strong">SKT, '개인정보 유출' 과징금 1,300억 원 취소 소송 제기</strong>,
#  <strong class="sa_text_strong">"AI표시 어디까지 넣어야 하나요"…법안 곳곳이 그레이존</strong>]

# %%
lst=[]
for i in range (5):
    lst.append(news_titles[i].text)
print(lst)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 3
#       1 lst=[]
#       2 for i in range (5):
# ----> 3     lst.append(news_titles[i].text)
#       4 print(lst)
#
# IndexError: list index out of range

# %%
title=news.select("h2#title_area>span")
#풀이

# %%
title[0].text
# Out:
# '과기정통부, 정부 연구개발 18개 기관과 예산 집행 ‘합동 설명회’ 개최'

# %%
news.select('a.sa_text_title._NLOG_IMPRESSION')
# Out:
# []

# %%
url='https://news.naver.com/section/105'
new=req.get(url)
news= bs(new.text,'lxml')
#풀이

# %%
new_url=news.select('a.sa_text_title._NLOG_IMPRESSION')

# %%
#get('속성명')
new_url[0].get('href')
# Out:
# 'https://n.news.naver.com/mnews/article/081/0003609700'

# %%
len(new_url)
# Out:
# 39

# %%
link_list=[]
for i in range(len(new_url)):
    link_list.append(new_url[i].get('href'))
    print(link_list[i])
# Out:
# https://n.news.naver.com/mnews/article/081/0003609700
# https://n.news.naver.com/mnews/article/421/0008722563
# https://n.news.naver.com/mnews/article/584/0000036110
# https://n.news.naver.com/mnews/article/015/0005239406
# https://n.news.naver.com/mnews/article/092/0002406733
# https://n.news.naver.com/mnews/article/018/0006203477
# https://n.news.naver.com/mnews/article/366/0001137159
# https://n.news.naver.com/mnews/article/015/0005239360
# https://n.news.naver.com/mnews/article/009/0005624177
# https://n.news.naver.com/mnews/article/009/0005624176
# https://n.news.naver.com/mnews/article/056/0012108258
# https://n.news.naver.com/mnews/article/003/0013719209
# https://n.news.naver.com/mnews/article/011/0004580652
# https://n.news.naver.com/mnews/article/421/0008722806
# https://n.news.naver.com/mnews/article/001/0015855535
# https://n.news.naver.com/mnews/article/366/0001137150
# https://n.news.naver.com/mnews/article/366/0001137148
# https://n.news.naver.com/mnews/article/421/0008722759
# https://n.news.naver.com/mnews/article/008/0005306609
# https://n.news.naver.com/mnews/article/023/0003954015
# https://n.news.naver.com/mnews/article/023/0003954011
# https://n.news.naver.com/mnews/article/023/0003954008
# https://n.news.naver.com/mnews/article/023/0003953961
# https://n.news.naver.com/mnews/article/016/0002587943
# https://n.news.naver.com/mnews/article/029/0003005818
# https://n.news.naver.com/mnews/article/020/0003690539
# https://n.news.naver.com/mnews/article/092/0002406715
# https://n.news.naver.com/mnews/article/016/0002587916
# https://n.news.naver.com/mnews/article/018/0006203362
# https://n.news.naver.com/mnews/article/469/0000909855
# https://n.news.naver.com/mnews/article/029/0003005806
# https://n.news.naver.com/mnews/article/016/0002587905
# https://n.news.naver.com/mnews/article/014/0005465135
# https://n.news.naver.com/mnews/article/092/0002406709
# https://n.news.naver.com/mnews/article/028/0002787222
# https://n.news.naver.com/mnews/article/008/0005306556
# https://n.news.naver.com/mnews/article/014/0005465087
# https://n.news.naver.com/mnews/article/014/0005465085
# https://n.news.naver.com/mnews/article/056/0012107863

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 new_url.select("h2")
#
# File ~\anaconda3\Lib\site-packages\bs4\element.py:2902, in ResultSet.__getattr__(self, key)
#    2900 def __getattr__(self, key: str) -> None:
#    2901     """Raise a helpful exception to explain a common code fix."""
# -> 2902     raise AttributeError(
#    2903         f"""ResultSet object has no attribute "{key}". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?"""
#    2904     )
#
# AttributeError: ResultSet object has no attribute "select". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
url='https://news.naver.com/section/105'
new=req.get(url)
news= bs(new.text,'lxml')
#풀이

# %%
data_list=[]
for i in range(len(link_list)):
    url=link_list[i]
    new=req.get(url)
    news= bs(new.text,'lxml')

    title=news.select("h2#title_area>span")[0].text
    content=news.select_one('article#dic_area').text.strip()
    data_list.append([title,content, url])

# %%
len(data_list)
# Out:
# 39

# %%
import pandas as pd

# %%
news_df=pd.DataFrame(data_list,columns=['뉴스제목','내용','링크'])

# %%
news_df.to_excel(r'C:\Users\jyc68\LG_DX_school_code\data\IT_과학 뉴스데이터 수집.xlsx')

# %%
# Out:
#   Cell In[78], line 1
#     |
#     ^
# SyntaxError: invalid syntax
