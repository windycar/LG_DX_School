# %%
from tqdm import tqdm
import pandas as pd
import requests as req 
from bs4 import BeautifulSoup as bs
import re
from kiwipiepy import Kiwi
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt
# 컴퓨터용 브라우저 -> 데이터 요청 및 응답 
from selenium import webdriver as wb
# 컴퓨터용 키보드 (Enter,Del 등 ) 컴퓨터에게 키보드를 전달하는 역할 
from selenium.webdriver.common.keys import Keys 
# 선택자를 구분할때 사용하는 라이브러리 (필수)
from selenium.webdriver.common.by import By
#쉬는 시간을 주는 라이브러리 
import time

# %%
def preprocess_sentence_kr(w):
  w = w.strip()
  w = re.sub(r"[^0-9가-힣?.!,¿a-zA-Z]+", " ", w) 
  w = w.strip() 
  return w

# %%
driver = wb.Chrome()
driver.get('https://www.naver.com/')
time.sleep(0.5)
search=driver.find_element(By.ID,'query')
search.send_keys('음식물 처리기')
search.send_keys(Keys.ENTER)
time.sleep(0.5)
#driver.find_element(By.CSS_SELECTOR,'#lnb > div.lnb_group > div > div.lnb_nav_area._nav_area_root > div > div.api_flicking_wrap._conveyer_root > div:nth-child(5) > a').click()
driver.find_elements(By.CSS_SELECTOR,'a.tab')[4].click()
driver.find_element(By.CSS_SELECTOR,'.spnew.ico_filter_arr').click()
time.sleep(0.5)
driver.find_elements(By.CSS_SELECTOR,'a.txt')[6].click()

# %%
body=driver.find_element(By.TAG_NAME,'body')
body.send_keys(Keys.END)
for i in range(10):
    body=driver.find_element(By.TAG_NAME,'body')
    body.send_keys(Keys.END)
    time.sleep(0.3)

# %%
# 순수한 url 을 담기 
#요소.get_attribute('속성명')
link_list=[]
aTag=driver.find_elements(By.CSS_SELECTOR,'a.fender-ui_228e3bd1._F4b_iMlsFBN3anLCC2o')
aTag[0].get_attribute('href')
for i in aTag:
     link_list.append(i.get_attribute('href'))
link_list
# Out:
# ['https://kin.naver.com/qna/detail.naver?d1id=8&dirId=802&docId=490510354&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=802&docId=491046605&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=413811604&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80201&docId=490688527&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=491234500&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31501&docId=489794339&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=490729449&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40703&docId=491489061&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=490856814&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=7&dirId=70601&docId=489114709&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8030104&docId=463042220&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110803&docId=489879801&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80105&docId=489964289&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8020203&docId=488808143&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=331390415&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=487973654&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1060102&docId=490631631&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=313&docId=490459413&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120309&docId=459624943&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=488527562&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1120&docId=488136388&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=488985720&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8030203&docId=489257521&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8020116&docId=487750201&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=501&docId=489524487&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=489846813&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=489523863&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=466204701&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=487973168&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=474000109&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=111606&docId=489572743&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=809&docId=476614014&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=7&dirId=707&docId=489862127&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31502&docId=490394892&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=802&docId=486967790&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80105&docId=489797034&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=490898862&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=802&docId=489816846&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=389630536&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8080103&docId=489269792&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=489279760&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40607&docId=488046642&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=490292817&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=488302013&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8030202&docId=488082340&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=488113776&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=479475691&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=61401&docId=484992037&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=389637357&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80801&docId=487368059&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80105&docId=415856413&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8020118&docId=490420783&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31506&docId=479489677&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=466491841&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=478714270&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=611&docId=475078738&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50704&docId=433614466&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=487979486&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1126&docId=489059256&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8020608&docId=490420751&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8020608&docId=466551205&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=806&docId=479870119&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8080103&docId=485098257&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40108&docId=423771959&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=480859389&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=488271370&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8080104&docId=488652204&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8080103&docId=490122279&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=501&docId=482606595&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31501&docId=488487917&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=511&docId=489874476&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80801&docId=489054826&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=802&docId=476937888&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1122&docId=489337546&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=490986157&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=480833276&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=389392729&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=484307345&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8020608&docId=488079530&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=441658274&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31501&docId=485572797&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=488467829&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=488193626&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40702&docId=475166450&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=501&docId=487624403&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31501&docId=486994735&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80801&docId=488253648&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=511&docId=490551353&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31506&docId=488194215&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=490435229&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=81105&docId=487745287&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1205&docId=488375578&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=487979526&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31302&docId=490497769&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=487972288&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=491133632&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90201&docId=490206734&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=449634822&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=809&docId=491336578&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90103&docId=489006657&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8020609&docId=489020998&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8020306&docId=461848624&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8080103&docId=490524030&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=467111307&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8020609&docId=489938310&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=111606&docId=487553046&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=468324623&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=488607553&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31501&docId=476895068&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=489425648&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D']

# %%
driver = wb.Chrome()
f=open('../../data/naver_data.txt','w',encoding='utf-8')
for i in tqdm(range(len(link_list))):
    driver.get(link_list[i])
    time.sleep(0.3)
    try:
        driver.find_element(By.CSS_SELECTOR,'#nextPageButton').click()
    except:
        pass
    a=driver.find_elements(By.CSS_SELECTOR,'.se-main-container')
    for j in a:
        content=preprocess_sentence_kr(j.text)
        f.write(content)
f.close()        
driver.quit()
# Out:
# 100%|██████████| 110/110 [02:45<00:00,  1.51s/it]

# %%
f=open('../../data/naver_data.txt','r',encoding='utf-8')
review=f.readline()
f.close()

# %%
kiwi=Kiwi()
#토큰화
token=kiwi.tokenize(review)

# %%
# 일반 명사만 추출 (NNG)
# token 의 리스트를 돌면서 tag가 NNG 인 form을 nng_list에 답으세요
nn_list=[]
for i in tqdm(token):
    if(i.tag=='NNG' or i.tag=='NNP'):
        nn_list.append(i.form)
# Out:
# 100%|██████████| 112553/112553 [00:00<00:00, 1482379.37it/s]

# %%
counter=Counter(nn_list)
top_100=counter.most_common(100)
top_100
# Out:
# [('음식물', 2092),
#  ('처리', 2056),
#  ('제품', 788),
#  ('방식', 745),
#  ('미생물', 568),
#  ('건조', 565),
#  ('사용', 497),
#  ('분쇄', 415),
#  ('쓰레기', 412),
#  ('냄새', 392),
#  ('환경', 291),
#  ('소음', 290),
#  ('확인', 289),
#  ('관리', 256),
#  ('지원', 242),
#  ('구매', 240),
#  ('가능', 236),
#  ('구입', 234),
#  ('렌탈', 233),
#  ('가정', 225),
#  ('추천', 223),
#  ('설치', 217),
#  ('지원금', 211),
#  ('필요', 202),
#  ('교체', 186),
#  ('물', 180),
#  ('필터', 178),
#  ('신청', 174),
#  ('후', 171),
#  ('싱크대', 164),
#  ('선택', 160),
#  ('비용', 160),
#  ('비교', 154),
#  ('지자체', 149),
#  ('전기료', 146),
#  ('발생', 144),
#  ('가격', 142),
#  ('문제', 142),
#  ('방법', 140),
#  ('배출', 140),
#  ('내부', 137),
#  ('안녕', 134),
#  ('참고', 131),
#  ('내용', 131),
#  ('후기', 130),
#  ('뼈', 128),
#  ('아래', 125),
#  ('고민', 124),
#  ('경우', 124),
#  ('불편', 124),
#  ('도움', 114),
#  ('때', 113),
#  ('답변', 111),
#  ('부담', 109),
#  ('미닉스', 107),
#  ('주방', 106),
#  ('악취', 106),
#  ('일반', 100),
#  ('정보', 100),
#  ('통', 99),
#  ('모델', 99),
#  ('브랜드', 97),
#  ('용량', 94),
#  ('정도', 92),
#  ('제공', 91),
#  ('최대', 91),
#  ('보조금', 90),
#  ('이유', 87),
#  ('기능', 87),
#  ('기준', 86),
#  ('정리', 86),
#  ('인증', 84),
#  ('문의', 82),
#  ('고려', 81),
#  ('분해', 81),
#  ('솥', 80),
#  ('편리', 79),
#  ('일부', 79),
#  ('성능', 78),
#  ('지역', 78),
#  ('스트레스', 76),
#  ('배관', 75),
#  ('전', 75),
#  ('중요', 75),
#  ('경제', 73),
#  ('점', 72),
#  ('걱정', 71),
#  ('질문', 71),
#  ('시간', 70),
#  ('작동', 70),
#  ('세척', 69),
#  ('국물', 69),
#  ('발효', 69),
#  ('위생', 68),
#  ('예산', 68),
#  ('관련', 68),
#  ('단점', 67),
#  ('다양', 67),
#  ('블로그', 66),
#  ('집', 65)]

# %%
wc = WordCloud(
    font_path='C:/Windows/Fonts/malgunbd.ttf',
    background_color='white'    
).generate_from_frequencies(dict(top_100))
plt.imshow(wc)
plt.axis('off')
plt.show()
