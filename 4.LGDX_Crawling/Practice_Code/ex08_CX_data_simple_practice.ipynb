# %%
from tqdm import tqdm
import pandas as pd
import requests as req 
from bs4 import BeautifulSoup as bs
import re
from kiwipiepy import Kiwi
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt
# 컴퓨터용 브라우저 -> 데이터 요청 및 응답 
from selenium import webdriver as wb
# 컴퓨터용 키보드 (Enter,Del 등 ) 컴퓨터에게 키보드를 전달하는 역할 
from selenium.webdriver.common.keys import Keys 
# 선택자를 구분할때 사용하는 라이브러리 (필수)
from selenium.webdriver.common.by import By
#쉬는 시간을 주는 라이브러리 
import time

# %%
def preprocess_sentence_kr(w):
  w = w.strip()
  w = re.sub(r"[^0-9가-힣?.!,¿a-zA-Z]+", " ", w) 
  w = w.strip() 
  return w

# %%
driver = wb.Chrome()
driver.get('https://www.naver.com/')
time.sleep(0.5)
search=driver.find_element(By.ID,'query')
search.send_keys('로봇 청소기')
search.send_keys(Keys.ENTER)
time.sleep(0.5)
#driver.find_element(By.CSS_SELECTOR,'#lnb > div.lnb_group > div > div.lnb_nav_area._nav_area_root > div > div.api_flicking_wrap._conveyer_root > div:nth-child(5) > a').click()
driver.find_elements(By.CSS_SELECTOR,'a.tab')[4].click()
driver.find_element(By.CSS_SELECTOR,'.spnew.ico_filter_arr').click()
time.sleep(0.5)
driver.find_elements(By.CSS_SELECTOR,'a.txt')[6].click()

# %%
body=driver.find_element(By.TAG_NAME,'body')
body.send_keys(Keys.END)
for i in range(10):
    body=driver.find_element(By.TAG_NAME,'body')
    body.send_keys(Keys.END)
    time.sleep(0.3)

# %%
# 순수한 url 을 담기 
#요소.get_attribute('속성명')
link_list=[]
aTag=driver.find_elements(By.CSS_SELECTOR,'a.fender-ui_228e3bd1._F4b_iMlsFBN3anLCC2o')
aTag[0].get_attribute('href')
for i in aTag:
     link_list.append(i.get_attribute('href'))
link_list
# Out:
# ['https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=490353779&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=491486422&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=474991440&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=491273941&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=363097853&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=491159366&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=491323757&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=491231695&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=414745594&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=487686378&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=487227068&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=462372505&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=489163074&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=489733381&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=489048532&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=431340712&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10105&docId=487461707&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=491486929&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=488794643&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=461947418&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=487295293&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10104&docId=488517015&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=485347250&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=488087066&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=489043255&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=81205&docId=487472307&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60207&docId=482766223&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=487309906&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=488541890&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=489792384&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=488994247&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=491253836&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=491324520&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=490409660&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=491387222&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=489238211&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=479561330&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=488846674&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=488294417&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=488709491&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=490538605&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=489879528&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=488836989&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=480337708&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80902&docId=491148450&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=327944645&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=488271696&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=487454085&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=487949330&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=456284078&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=363182977&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=397480964&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=403547587&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=484139838&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=491407547&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=488348638&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=491458882&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=485384109&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=483199230&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=490501343&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=490832169&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=474232321&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=487531114&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=488655247&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=491189400&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=490103618&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=364343421&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=491449660&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=366752803&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10203&docId=484970044&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=397288471&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=391424555&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=488904190&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=491230802&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8080101&docId=487001355&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=490989777&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=491253695&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=490417481&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=485606244&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=490624052&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=434341071&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=392936590&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=489326201&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80902&docId=490602786&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=491187733&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=483213052&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=401233669&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=488573358&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=400712282&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=468933096&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=433310927&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=427814347&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=449898756&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=487418521&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10203&docId=490884042&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=402050865&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40401&docId=442392914&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=476623491&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1118&docId=488571325&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=491411731&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=477535015&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=11001&docId=486377197&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=491514729&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=491313948&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=490552890&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90101&docId=491044725&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=488826274&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=442118272&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=486376628&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50704&docId=487346239&enc=utf8&kinsrch_src=pc_tab_kin&qb=66Gc67SHIOyyreyGjOq4sA%3D%3D']

# %%
driver = wb.Chrome()
f=open('../../data/naver_robot.txt','w',encoding='utf-8')
for i in tqdm(range(len(link_list))):
    driver.get(link_list[i])
    time.sleep(0.3)
    try:
        driver.find_element(By.CSS_SELECTOR,'#nextPageButton').click()
    except:
        pass
    a=driver.find_elements(By.CSS_SELECTOR,'.se-main-container')
    for j in a:
        content=preprocess_sentence_kr(j.text)
        f.write(content)
f.close()        
driver.quit()
# Out:
# 100%|██████████| 110/110 [03:03<00:00,  1.67s/it]

# %%
f=open('../../data/naver_robot.txt','r',encoding='utf-8')
review=f.readline()
f.close()

# %%
kiwi=Kiwi()
#토큰화
token=kiwi.tokenize(review)

# %%
# 일반 명사만 추출 (NNG)
# token 의 리스트를 돌면서 tag가 NNG 인 form을 nng_list에 답으세요
nn_list=[]
for i in tqdm(token):
    if(i.tag=='NNG' or i.tag=='NNP'):
        nn_list.append(i.form)
# Out:
# 100%|██████████| 78790/78790 [00:00<00:00, 746301.93it/s]

# %%
counter=Counter(nn_list)
top_100=counter.most_common(100)
top_100
# Out:
# [('청소기', 1060),
#  ('로봇', 912),
#  ('제품', 500),
#  ('청소', 429),
#  ('기능', 361),
#  ('가능', 291),
#  ('물걸레', 282),
#  ('모델', 278),
#  ('사용', 267),
#  ('확인', 219),
#  ('추천', 199),
#  ('렌탈', 197),
#  ('자동', 193),
#  ('구매', 188),
#  ('흡입력', 175),
#  ('먼지', 165),
#  ('비교', 149),
#  ('성능', 148),
#  ('후', 137),
#  ('센서', 134),
#  ('배터리', 133),
#  ('세척', 128),
#  ('앱', 126),
#  ('방법', 125),
#  ('로보', 125),
#  ('답변', 123),
#  ('락', 121),
#  ('문제', 119),
#  ('고객', 112),
#  ('집', 112),
#  ('선택', 111),
#  ('설치', 109),
#  ('가격', 109),
#  ('경우', 106),
#  ('인식', 106),
#  ('브랜드', 101),
#  ('흡입', 101),
#  ('삼성', 101),
#  ('필요', 100),
#  ('서비스', 100),
#  ('점', 99),
#  ('때', 99),
#  ('관리', 96),
#  ('창문', 96),
#  ('해결', 95),
#  ('정보', 93),
#  ('다양', 92),
#  ('설정', 90),
#  ('안녕', 89),
#  ('센터', 89),
#  ('문의', 88),
#  ('사용자', 87),
#  ('충전', 85),
#  ('가성비', 85),
#  ('장애물', 84),
#  ('쿠팡', 82),
#  ('참고', 81),
#  ('제공', 81),
#  ('스테이션', 81),
#  ('교체', 81),
#  ('수리', 80),
#  ('도움', 79),
#  ('시간', 76),
#  ('상담', 74),
#  ('지원', 72),
#  ('가전', 72),
#  ('이상', 71),
#  ('스마트', 69),
#  ('후기', 69),
#  ('연결', 67),
#  ('필터', 66),
#  ('작동', 65),
#  ('증상', 65),
#  ('동일', 65),
#  ('편리', 63),
#  ('바닥', 63),
#  ('회피', 62),
#  ('털', 61),
#  ('무선', 61),
#  ('보증', 61),
#  ('고장', 60),
#  ('정리', 60),
#  ('통', 59),
#  ('고려', 58),
#  ('공식', 58),
#  ('아래', 57),
#  ('접수', 57),
#  ('최신', 55),
#  ('건조', 55),
#  ('전자', 54),
#  ('내용', 54),
#  ('곳', 54),
#  ('배수', 54),
#  ('카펫', 53),
#  ('리뷰', 52),
#  ('포함', 52),
#  ('방식', 51),
#  ('반복', 51),
#  ('생각', 50),
#  ('카메라', 50)]

# %%
wc = WordCloud(
    font_path='C:/Windows/Fonts/malgunbd.ttf',
    background_color='white'    
).generate_from_frequencies(dict(top_100))
plt.imshow(wc)
plt.axis('off')
plt.show()
