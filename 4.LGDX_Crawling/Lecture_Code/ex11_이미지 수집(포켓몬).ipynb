# %% [markdown]
# ### 학습목표
# - 웹페이지에 있는 이미지데이터를 수집하여 로컬컴퓨터에 저장하는 방법에 대해서 알 수 있다.
# - 파일관리 시스템을 활용하여 코드로 폴더 및 파일관리법에 대해서 알 수 있다.

# %%
# 라이브러리 불러오기
from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from tqdm import tqdm

# 파일이나 폴더를 생성,삭제해주는 파일관리시스템 라이브러리
import os #Operationg System
# 이미지의 경로(주소)를 로컬파일로 변환해주는 라이브러리
from urllib.request import urlretrieve

# %% [markdown]
# - os 라이브러리
# > - 파일관리시스템을 위한 라이브러리
# > - 파일, 폴더 등을 생성, 삭제 관리하는 라이브러리
# - urllib.request
# > - url 주소를 열어 타 용도로 사용하는 라이브러리
# > - urlretrieve: url 주소를 파일로 저장

# %%
# 현재 파일의 경로
os.getcwd()
# Out:
# 'C:\\Users\\smhrd\\LGDX_study\\3.LGDX_Crawling'

# %%
# 현재 폴더내의 리스트 출력 / 소괄호 안쪽에 경로를 작성하면 해당 경로의 리스트도 확인가능
os.listdir('./data/')
# Out:
# ['.ipynb_checkpoints',
#  'han.jpg',
#  'heart.jpg',
#  'IT_과학 뉴스데이터 수집.xlsx',
#  'movie_review.txt',
#  '네이버 블로그 수집.txt',
#  '네이버 지식인 리뷰데이터.txt']

# %%
# 코드로 폴더 생성
# os.mkdir('경로')  -> 경로를 복사할때 역슬래시는 이스케이프 코드 -> 역슬래시 2개
os.mkdir('C:\\Users\\smhrd\\Desktop\\포켓몬')
# 현재 위치에 동일한 폴더명으로 생성은 불가능!
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[6], line 3
#       1 # 코드로 폴더 생성
#       2 # os.mkdir('경로')  -> 경로를 복사할때 역슬래시는 이스케이프 코드 -> 역슬래시 2개
# ----> 3 os.mkdir('C:\\Users\\smhrd\\Desktop\\포켓몬')
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'C:\\Users\\smhrd\\Desktop\\포켓몬'

# %%
# 페이지 정보 요청
url = 'https://www.pokemonkorea.co.kr/pokedex#pokedex_1'
driver = wb.Chrome()
driver.get(url)

# %%
# 이미지의 src 수집하여 img_list 에 담기
img = driver.find_elements(By.CSS_SELECTOR,'img.img-fluid')
img[0].get_attribute('src')
# Out:
# 'https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000101.png'

# %%
img_list = []
for i in img:
    img_list.append(i.get_attribute('src'))

# %%
img_list
# Out:
# ['https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000101.png',
#  'https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000201.png',
#  'https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000301.png',
#  'https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000302.png',
#  'https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000303.png',
#  'https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000401.png',
#  'https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000501.png',
#  'https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000601.png',
#  'https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000602.png',
#  'https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000603.png',
#  'https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000604.png',
#  'https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000701.png',
#  'https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000801.png',
#  'https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000901.png',
# ...
